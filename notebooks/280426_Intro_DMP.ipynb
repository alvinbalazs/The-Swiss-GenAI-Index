# %%
pwd
# Out:
# '/Users/alvin-marcusbalazs'

# %%
cd '/Users/alvin-marcusbalazs/Desktop/PhD/Seminars/Intro to Data Management Plan'
# Out:
# /Users/alvin-marcusbalazs/Desktop/PhD/Seminars/Intro to Data Management Plan

# %% [markdown]
# # Author Information

# %% [markdown]
# Author: Balazs Alvin
#
# E-Mail: alvin.balazs@unibe.ch

# %% [markdown]
# ## Subheader

# %% [markdown]
# * list item 1

# %% [markdown]
# # Analysis Start

# %%
room_temp=34/3

# %%
room_temp
# Out:
# 11.333333333333334
